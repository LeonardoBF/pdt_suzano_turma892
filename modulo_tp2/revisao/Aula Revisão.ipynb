# %% [markdown]
# # Aula Revisão

# %% [markdown]
# ### Documentações

# %% [markdown]
# 1. [Documentação Pandas Plot](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html)
# 2. [Documentação Matplotlib](https://matplotlib.org/stable/tutorials/introductory/usage.html)
# 3. [Documentação Seaborn](https://seaborn.pydata.org/tutorial/introduction.html)
# 4. [Documentação Plotly Express](https://plotly.com/python-api-reference/plotly.express.html)
# 5. [Documentação Streamlit](https://docs.streamlit.io/library/api-reference)

# %% [markdown]
# ### Instalação Bibliotecas

# %%
# # Instalando a biblioteca
# !pip install pandas
# !pip install seaborn
# !pip install matplotlib
# !pip install plotly
# !pip install streamlit

# %% [markdown]
# ### Importanto Bibliotecas e Configurações

# %%
# importando a biblioteca
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Resolvendo Problemas com Gráficos

# %% [markdown]
# **Processo de plotagem:**
#
# **1. Qual a base de dados?**
#
#    Entendimento da base de dados
#
#
# **2. Qual a pergunta de negócio para responder?**
#
#    Entendimento da questão de negócio
#
#
# **3. Qual o formato que os dados precisam estar?**
#
#    Transformação dos dados
#
#
# **4. Qual o melhor gráfico para exibir os dados?**
#
#    Realização da plotagem do gráfico

# %% [markdown]
# #### Base de Dados

# %%
# base de dados de carros
mpg = sns.load_dataset('mpg')
mpg.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
# base de dados d voos
flights = sns.load_dataset('flights')
flights.head(2)
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118

# %% [markdown]
# #### Gráfico de Barras

# %% [markdown]
# * Comparativo entre dados categóricos
# * Comparativos mensais e anuais
# * Exemplo: Comparar o total de vendas por estado

# %%
 # quantidade de carro por origem
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
mpg.origin.value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
# pandas
mpg.origin.value_counts().plot.bar();

# %%
# matplotlib
x_bar = mpg.origin.value_counts().index
y_bar = mpg.origin.value_counts().values
plt.bar(x_bar, y_bar)
plt.show()

# %%
# seaborn
sns.countplot(data=mpg, x='origin');

# %%
# plotly
px.bar(data_frame=mpg, x='origin')

# %%
# plotly
x_bar = mpg.origin.value_counts().index
y_bar = mpg.origin.value_counts().values
px.bar(x=x_bar, y=y_bar)

# %%
# plotly
px.histogram(data_frame=mpg, x='origin')

# %%
# seaborn
sns.barplot(data=mpg, x='origin', y='acceleration', estimator=np.mean, errorbar=None);

# %% [markdown]
# #### Gráfico de Linhas

# %% [markdown]
# * Evolução de um atributo no tempo
# * Demonstrar sequência de um valor durante anos, meses, semanas ou dias
# * Exemplo: Vendas durante os meses de um determinado ano

# %%
# evolução de voos por mês ao longo dos anos
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
# pivotamento de flights
# df.pivot(index, columns, values)

flights.pivot('year', 'month', 'passengers')
# Out:
# /tmp/ipykernel_1052195/2139403859.py:4: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
# pandas
flights.pivot('year', 'month', 'passengers').plot.line()
# Out:
# /tmp/ipykernel_1052195/290562471.py:2: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
# <AxesSubplot: xlabel='year'>

# %%
flights.pivot('year', 'month', 'passengers')
# Out:
# /tmp/ipykernel_1052195/3654140845.py:1: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
flights_pivot[col].index
flights_pivot[col].values
# Out:
# year
# 1949    112
# 1950    115
# 1951    145
# 1952    171
# 1953    196
# 1954    204
# 1955    242
# 1956    284
# 1957    315
# 1958    340
# 1959    360
# 1960    417
# Name: Jan, dtype: int64

# %%
# matplotlib

flights_pivot = flights.pivot('year', 'month', 'passengers')

for col in flights_pivot.columns:
    x_line = flights_pivot[col].index
    y_line = flights_pivot[col].values
    plt.plot(x_line, y_line, label=col)

# plt.plot(flights_pivot)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_1052195/2684028015.py:3: FutureWarning:
#
# In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.

# %%
# seaborn
sns.lineplot(data=flights,
             x='year',
             y='passengers',
             estimator='mean');

# %%
# plotly
px.line(data_frame=flights,
        x='year',
        y='passengers',
        line_group='month',
        color='month')

# %% [markdown]
# #### Gráfico de Dispersão

# %% [markdown]
# * Visão de comparação entre duas variáveis
# * Indica o quantos uma variável pode ou não influenciar a outra
# * Exemplo: Tempo de profissão e salário

# %%
# potência x aceleração dos carros
mpg.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
# pandas
mpg.plot.scatter(x='horsepower', y='acceleration');

# %%
# matplotlib
x_scatter = mpg.horsepower
y_scatter = mpg.acceleration
plt.scatter(x_scatter, y_scatter)
plt.show()

# %%
# seaborn
sns.scatterplot(data=mpg,
                x='horsepower',
                y='acceleration');

# %%
# plotly
px.scatter(data_frame=mpg,
           x='horsepower',
           y='acceleration')

# %% [markdown]
# #### Histograma

# %% [markdown]
# * Visão de distribuição de uma variável
# * Analisa a frequência/quantidade de uma coluna
# * Similar ao gráfico de coluna, mas busca responder perguntas sobre a distribuição
# * Exemplo: Faixa etária dos inscritos no enem

# %%
# verificando o aceleração dos carros
mpg.acceleration.head(10)
# Out:
# 0    12.0
# 1    11.5
# 2    11.0
# 3    12.0
# 4    10.5
# 5    10.0
# 6     9.0
# 7     8.5
# 8    10.0
# 9     8.5
# Name: acceleration, dtype: float64

# %%
# pandas
mpg.acceleration.plot.hist();

# %%
# matplotlib
plt.hist(mpg.acceleration)
plt.show()

# %%
# seaborn
sns.histplot(data=mpg, x='acceleration');

# %%
# plotly
px.histogram(data_frame=mpg, x='acceleration')

# %% [markdown]
# #### Gráfico de Caixa

# %% [markdown]
# * Visão de distribuição de uma variável
# * Identificação de outliers
# * Apresenta algumas respostas importantes sobre o dado em análise
# * Exemplo: A distribuição dos salários em uma empresa

# %%
# dispersão dos dados de potência dos carros
mpg.horsepower.head(10)
# Out:
# 0    130.0
# 1    165.0
# 2    150.0
# 3    150.0
# 4    140.0
# 5    198.0
# 6    220.0
# 7    215.0
# 8    225.0
# 9    190.0
# Name: horsepower, dtype: float64

# %%
# pandas
mpg.horsepower.plot.box();

# %%
mpg.horsepower.isna().sum()
# Out:
# 6

# %%
# matplolib
plt.boxplot(x=mpg.horsepower.dropna(), vert=True)
plt.show()

# %%
# seaborn
sns.boxplot(data=mpg, y='horsepower');

# %%
# plotly
px.box(data_frame=mpg, y='horsepower')

# %% [markdown]
# ### Resumo Gráficos Python

# %% [markdown]
# ![resumo graficos](resumo_graficos.png)

# %% [markdown]
# ### Streamlit

# %%
import streamlit as st

# %%
# escrevendo título
st.title()
st.header()

# %%
# escrevendo subtitulo
st.subheader()

# %%
# escrevendo texto
st.write()
st.text()

# %%
# escrevendo com linguagem markdown
st.markdown()

# %%
# exibindo um dataframe
st.write()
st.dataframe()

# %%
# exibindo uma tabela
st.table()

# %%
# plotando um gráfico pandas plot
fig, ax = plt.subplots()
dataframe.plot.hist()
st.pyplot(fig)

# %%
# plotando um gráfico matplotlib
fig, ax = plt.subplots()
ax.hist()
st.pyplot(fig)

# %%
# plotando um gráfico seaborn
fig, ax = plt.subplots()
sns.histplot(ax=ax)
st.pyplot(fig)

# %%
# plotando um gráfico plotly
fig = px.hisogram()
st.plotly_chart(fig)

# %%
# criando um botão
st.button()

# %%
# criando um checkbox
st.checkbox()

# %%
# criando um selectbox
st.selectbox()

# %%
# criando um input de texto do usuário
st.text_input()

# %%
Grupo 1
- Marina Maracajá
- Marcelo Mesquita
- Filipe Sousa
- Guilherme Oliveira 

Grupo 2 
- Paulo
-Jean
-Mateus
-Francisco
-Lucas

Grupo 3
- Cintia Dantas
- Julia
- Junior Aguiar 
- Rafael 

Grupo 4
- Ana Carolina
- Kaio Henrique 
- Ana Carolina A.
- Carlos
- Gabriel Mariusso

Grupo 5
- Elizabeth Oliveira
- Elton Lima
- Enzo dos Santos
- Gabriel Filipe
